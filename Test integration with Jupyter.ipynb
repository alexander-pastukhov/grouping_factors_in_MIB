# %% [markdown]
# # This is just a test

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
xtick= np.linspace(-np.pi*2, np.pi*2, num=100)
plt.plot(xtick, np.cos(xtick), 'b-')
plt.show()
